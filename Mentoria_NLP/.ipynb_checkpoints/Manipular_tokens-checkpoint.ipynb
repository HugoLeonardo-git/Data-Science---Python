# %%
pip install youtube-transcript-api==0.6.2
# Out:
# Collecting youtube-transcript-api==0.6.2
#   Downloading youtube_transcript_api-0.6.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: requests in c:\users\hugoleonardo\anaconda3\lib\site-packages (from youtube-transcript-api==0.6.2) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hugoleonardo\anaconda3\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hugoleonardo\anaconda3\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hugoleonardo\anaconda3\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hugoleonardo\anaconda3\lib\site-packages (from requests->youtube-transcript-api==0.6.2) (2025.4.26)
# Downloading youtube_transcript_api-0.6.2-py3-none-any.whl (24 kB)
# Installing collected packages: youtube-transcript-api
#   Attempting uninstall: youtube-transcript-api
#     Found existing installation: youtube-transcript-api 1.2.3
#     Uninstalling youtube-transcript-api-1.2.3:
#       Successfully uninstalled youtube-transcript-api-1.2.3
# Successfully installed youtube-transcript-api-0.6.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import yt_dlp
import whisper
import os

def transcrever_youtube_yt_dlp(url, modelo="small", nome_arquivo="transcricao_youtube.txt"):
    # Passo 1: Baixar áudio com yt-dlp
    print("⏳ Baixando áudio com yt-dlp...")
    audio_path = "audio_temp.mp3"
    ydl_opts = {
        'format': 'bestaudio/best',
        'outtmpl': audio_path,
        'quiet': True,
        'no_warnings': True,
        'noplaylist': True,
    }
    with yt_dlp.YoutubeDL(ydl_opts) as ydl:
        ydl.download([url])
    print(f"✅ Áudio baixado em: {audio_path}")

    # Passo 2: Carregar modelo Whisper
    print(f"⏳ Carregando modelo Whisper ({modelo})...")
    model = whisper.load_model(modelo)

    # Passo 3: Transcrever áudio
    print("⏳ Transcrevendo áudio...")
    result = model.transcribe(audio_path, language="pt")
    texto = result["text"]
    print("✅ Transcrição concluída.")

    # Passo 4: Salvar transcrição
    with open(nome_arquivo, "w", encoding="utf-8") as f:
        f.write(texto)
    print(f"✅ Transcrição salva em: {nome_arquivo}")

    # Remover arquivo temporário
    os.remove(audio_path)

    return texto

# === Exemplo de uso ===
url_video = "https://www.youtube.com/watch?v=4bkrcEUBr-k"
transcricao = transcrever_youtube_yt_dlp(url_video, modelo="small")
print("=== Início da transcrição ===")
print(transcricao[:500])
# Out:
# ⏳ Baixando áudio com yt-dlp...
# ✅ Áudio baixado em: audio_temp.mp3
# ⏳ Carregando modelo Whisper (small)...
# ⏳ Transcrevendo áudio...
# C:\Users\HugoLeonardo\anaconda3\Lib\site-packages\whisper\transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# ✅ Transcrição concluída.
# ✅ Transcrição salva em: transcricao_youtube.txt
# === Início da transcrição ===
#  Olá, tudo bem? Meu nome é Jaini Figueira, eu sou chefe de cozinha e hoje eu vou fazer um doce italiano maravilhoso que se chama Zabaione. É uma coisa muito fácil de se fazer, tá? Aqui no Brasil a gente pode chamar de uma gemada, mas é uma gemada chique, é uma gemada elaborada, porque a gente vai usar nela um vinho licoroso, aqui hoje eu estou com um vinho mais sala, mas também você pode usar um vinho santo, pode usar um xerez, pode usar um vinho do porto, que é mais comum, mais fácil de achar.
